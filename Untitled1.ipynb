# %%
import sys
sys.path.insert(1,"/Users/mkurka/git/h2o/h2o-3/h2o-py")

# %%
import h2o

# %%
h2o.connect()
# Out:
# Connecting to H2O server at http://localhost:54321 ... successful.
# --------------------------  ------------------------------------------------------------------
# H2O_cluster_uptime:         12 secs
# H2O_cluster_timezone:       America/New_York
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.31.0.99999
# H2O_cluster_version_age:    23 minutes
# H2O_cluster_name:           mkurka
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    3.540 Gb
# H2O_cluster_total_cores:    8
# H2O_cluster_allowed_cores:  8
# H2O_cluster_status:         accepting new members, healthy
# H2O_connection_url:         http://localhost:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# H2O_API_Extensions:         Amazon S3, XGBoost, Algos, AutoML, Core V3, TargetEncoder, Core V4
# Python_version:             2.7.14 final
# --------------------------  ------------------------------------------------------------------
# ...

# %%
mp_loc = "/Users/mkurka/Downloads/atest/mojo-pipeline"
mojo = h2o.import_file("/Users/mkurka/Downloads/atest/mojo-pipeline/pipeline.mojo", parse=False)
mojo_key = mojo[0]
data = h2o.import_file("/Users/mkurka/Downloads/atest/mojo-pipeline/example.csv")
h2o.rapids("(assign scored (mojo.pipeline.transform %s %s true))" % (mojo_key, data.key))
h2o.get_frame("scored")
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# <table>
# <thead>
# ...

# %%
data
# Out:
# <table>
# <thead>
# ...
